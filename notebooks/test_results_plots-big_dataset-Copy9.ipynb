# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import xarray as xr
import torch

import sys
import os.path

sys.path.append(os.path.dirname(os.getcwd()))

from utils.train_test_utils import load_dataset, DatasetParameters


plt.rcParams['figure.figsize'] = (15, 7)

# %%
run_dir = "../output/20220508_161454"

# %%
dataset = xr.open_dataarray(f"../data/stocks_daily/stocks_big_dataset_2022-0425.nc")
train_df = pd.read_csv(f"{run_dir}/train_log.csv")
test_df = pd.read_csv(f"{run_dir}/test_results.csv", parse_dates=['Unnamed: 0']).rename({'Unnamed: 0': 'time'}, axis=1)

plt.figure(figsize=(15,15))
plt.subplot(311)
sns.lineplot(x='epoch', y='train_loss', data=train_df)
# sns.lineplot(x='epoch', y='test_loss', data=train_df)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title("Train loss")
# plt.legend(labels=["Train", "Test"])

plt.subplot(312)

# sns.lineplot(x='epoch', y='train_apv', data=train_df)

sns.lineplot(x='epoch', y='test_apv', data=train_df, color='orange')
plt.ylabel('Portfolio value')
plt.xlabel('Step')
plt.title("Test APV")

plt.subplot(313)

sns.lineplot(x='epoch', y='test_loss', data=train_df, color='orange')
plt.ylabel('Test loss')
plt.xlabel('Step')
plt.title("Test Loss")

# plt.legend(labels=["Train", "Test"])
# Out:
# Text(0.5, 1.0, 'Test Loss')

# %%
train_df.columns
# Out:
# Index(['time', 'epoch', 'train_loss', 'train_apv', 'test_loss', 'test_apv'], dtype='object')

# %%
best_epoch = train_df.iloc[np.argmax(train_df['test_apv'])]['epoch']

# %%
best_epoch
# Out:
# 200

# %%
assets = [re.sub(r"^asset_", "", col) for col in test_df.columns if col.startswith('asset_')]
assets = list(filter(lambda asset: asset != "cash", assets)) + ['cash']

for asset in assets:
    sns.lineplot(x='time', y=f'asset_{asset}', data=test_df)
    
plt.legend(labels=[asset.upper() for asset in assets])
plt.xlabel('Time')
plt.ylabel('Part of portfolio')
# Out:
# Text(0, 0.5, 'Part of portfolio')

# %%
for asset in assets:
    if asset == "cash":
        continue
    asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
    asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index <= test_df['time'].iloc[-1])]

    sns.lineplot(data=asset_data/asset_data[0])
    
    
plt.legend(labels=[asset.upper() for asset in assets if asset != "cash"])
plt.xlabel('Time')
plt.ylabel('Price change')
# Out:
# Text(0, 0.5, 'Price change')

# %%
for asset in assets:
    if asset == "cash":
        continue
    asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
    asset_data = asset_data[asset_data.index >= '2010']

    sns.lineplot(data=asset_data/asset_data[0])
    
    
plt.legend(labels=[asset.upper() for asset in assets if asset != "cash"])
plt.xlabel('Time')
plt.ylabel('Price change')
# Out:
# Text(0, 0.5, 'Price change')

# %%
plt.figure(figsize=(15, 7))

asset = 'msft'

asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index <= test_df['time'].iloc[-1])]

ax = sns.lineplot(data=asset_data)
plt.ylabel(f'{asset.upper()} price')
ax2 = ax.twinx()
plt.ylabel(f'Portfolio part')


sns.lineplot(x='time', y=test_df[f'asset_{asset}'], data=test_df, ax=ax2, color='orange')
# Out:
# <AxesSubplot:xlabel='time', ylabel='Portfolio part'>

# %%
plt.figure(figsize=(15, 7))

ax = sns.lineplot(x='time', y=test_df[f'asset_{asset}'], data=test_df, color='orange')

plt.ylabel(f'Portfolio part')
ax2 = ax.twinx()
plt.ylabel(f'Price change')

sns.lineplot(x='time', y=test_df[f'price_change_{asset}'], data=test_df, ax=ax2, color='red')
# Out:
# <AxesSubplot:xlabel='time', ylabel='Price change'>

# %%
# plt.figure(figsize=(15, 7))


# asset = 'spy'

# asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
# asset_data = asset_data[asset_data.index >= test_df['time'][0]]
# # asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index < '2008-12-01')]


# plt.title('Our results vs S&P 500')
# sns.lineplot(x='time', y='portfolio_value', data=test_df, color='lime')
# sns.lineplot(data=asset_data/asset_data[0])

# %%
test_df.head()
# Out:
#         time  asset_cash  asset_xom  asset_ge  asset_msft   asset_c   asset_t  \
# 0 2010-06-16    0.011486   0.082291  0.082757    0.082487  0.082323  0.082207
# 1 2010-06-17    0.011662   0.082278  0.082635    0.082599  0.082219  0.082190
# 2 2010-06-18    0.011668   0.082268  0.082666    0.082478  0.082180  0.082149
# 3 2010-06-21    0.011708   0.082272  0.082487    0.082476  0.082274  0.082139
# 4 2010-06-22    0.011724   0.082251  0.082517    0.082440  0.082160  0.082212
#
#    asset_bac  asset_pg  asset_wmt  ...  price_change_msft  price_change_c  \
# 0   0.082460  0.082186   0.082108  ...           1.042655        1.028350
# 1   0.082365  0.082218   0.082304  ...           0.990125        1.000000
# 2   0.082386  0.082261   0.082330  ...           1.001900        0.992481
# 3   0.082384  0.082302   0.082362  ...           1.002655        1.012626
# 4   0.082353  0.082338   0.082374  ...           0.981468        1.002494
#
#    price_change_t  price_change_bac  price_change_pg  price_change_wmt  \
# 0        1.014700          1.025243         1.010776          1.007806
# 1        0.999217          1.004494         0.988370          0.987219
# 2        1.001959          0.996849         1.009315          1.008435
# 3        0.994525          1.000000         0.992552          1.002723
# 4        1.000393          0.998104         0.996737          0.989719
#
#    price_change_pfe  price_change_mo  price_change_aig  price_change_jnj
# 0          1.012394         1.017374          1.021300          1.012325
# 1          0.997423         0.995982          0.999736          1.001691
# 2          0.999354         1.008069          0.997359          0.998987
# 3          0.983193         1.001501          1.003707          1.000000
# 4          0.992768         1.001998          1.022422          0.999155
#
# [5 rows x 28 columns]

# %%
assets = ['XOM', 'GE', 'MSFT', 'C', 'T', 'BAC', 'PG', 'WMT', 'PFE', 'MO', 'AIG', 'JNJ']

dataset_params = DatasetParameters(
    dataset='../data/stocks_daily/stocks_big_dataset_2022-0425.nc',
    x_window_size=30,
    batch_size=128,
    dataset_date_range=slice('2006-06-01', None),
    dataset_features=['close', 'high', 'low', 'open'],
    dataset_assets=assets,
    train_range=('2010-06-29', '2020-05-01'),
    validation_range=('2020-05-01', '2021-05-01'),
#     test_range=(test_df['time'].iloc[0], test_df['time'].iloc[-1])
    test_range=('2021-05-03', '2022-04-22')
)

dm = load_dataset(dataset_params)

test_ds = dm.get_test_set_online(assets, dm._test_ind[0], dm._test_ind[-1], 30)

trivial_model_distribution = test_ds['y'][:, 0, :, :].squeeze()

# result = gains.prod(axis=0).mean()
# gain = result - 1

# %%
trivial_model_performance = np.cumprod(trivial_model_distribution, axis=0).mean(axis=1)
trivial_model_performance = np.concatenate([[1], trivial_model_performance])

# %%
asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index <= test_df['time'].iloc[-1])]

asset_data.shape
# Out:
# (2485,)

# %%
trivial_model_performance.shape
# Out:
# (13,)

# %%
test_df['time'][0]
# Out:
# Timestamp('2010-06-16 00:00:00')

# %%
asset_data.index[0]
# Out:
# Timestamp('2010-06-16 00:00:00')

# %%
test_df['time'][0]
# Out:
# Timestamp('2010-06-16 00:00:00')

# %%
test_df.head()
# Out:
#         time  asset_cash  asset_xom  asset_ge  asset_msft   asset_c   asset_t  \
# 0 2010-06-16    0.011486   0.082291  0.082757    0.082487  0.082323  0.082207
# 1 2010-06-17    0.011662   0.082278  0.082635    0.082599  0.082219  0.082190
# 2 2010-06-18    0.011668   0.082268  0.082666    0.082478  0.082180  0.082149
# 3 2010-06-21    0.011708   0.082272  0.082487    0.082476  0.082274  0.082139
# 4 2010-06-22    0.011724   0.082251  0.082517    0.082440  0.082160  0.082212
#
#    asset_bac  asset_pg  asset_wmt  ...  price_change_msft  price_change_c  \
# 0   0.082460  0.082186   0.082108  ...           1.042655        1.028350
# 1   0.082365  0.082218   0.082304  ...           0.990125        1.000000
# 2   0.082386  0.082261   0.082330  ...           1.001900        0.992481
# 3   0.082384  0.082302   0.082362  ...           1.002655        1.012626
# 4   0.082353  0.082338   0.082374  ...           0.981468        1.002494
#
#    price_change_t  price_change_bac  price_change_pg  price_change_wmt  \
# 0        1.014700          1.025243         1.010776          1.007806
# 1        0.999217          1.004494         0.988370          0.987219
# 2        1.001959          0.996849         1.009315          1.008435
# 3        0.994525          1.000000         0.992552          1.002723
# 4        1.000393          0.998104         0.996737          0.989719
#
#    price_change_pfe  price_change_mo  price_change_aig  price_change_jnj
# 0          1.012394         1.017374          1.021300          1.012325
# 1          0.997423         0.995982          0.999736          1.001691
# 2          0.999354         1.008069          0.997359          0.998987
# 3          0.983193         1.001501          1.003707          1.000000
# 4          0.992768         1.001998          1.022422          0.999155
#
# [5 rows x 28 columns]

# %%
plt.figure(figsize=(15, 7))


asset = 'spy'

asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index <= test_df['time'].iloc[-1])]
# asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index < '2008-12-01')]

# our_model = np.concatenate([[1], test_df['portfolio_value']])

plt.title('Our results vs Buy & Hold')
sns.lineplot(x='time', y='portfolio_value', data=test_df, color='limegreen')

sns.lineplot(x=test_df['time'][:-1], y=trivial_model_performance[1:], color='cornflowerblue')

sns.lineplot(data=asset_data/asset_data[0], color='maroon')

plt.legend(labels=["Our model", "Buy & hold", "S&P 500"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [726], in <cell line: 15>()
#      12 plt.title('Our results vs Buy & Hold')
#      13 sns.lineplot(x='time', y='portfolio_value', data=test_df, color='limegreen')
# ---> 15 sns.lineplot(x=test_df['time'][:-1], y=trivial_model_performance[1:], color='cornflowerblue')
#      17 sns.lineplot(data=asset_data/asset_data[0], color='maroon')
#      19 plt.legend(labels=["Our model", "Buy & hold", "S&P 500"])
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/relational.py:692, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     677 @_deprecate_positional_args
#     678 def lineplot(
#     679     *,
#    (...)
#     688     legend="auto", ax=None, **kwargs
#     689 ):
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#     695         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#     696     )
#     698     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     699     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/relational.py:367, in _LinePlotter.__init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     353 def __init__(
#     354     self, *,
#     355     data=None, variables={},
#    (...)
#     361     # the kind of plot to draw, but for the time being we need to set
#     362     # this information so the SizeMapping can use it
#     363     self._default_size_range = (
#     364         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     365     )
# --> 367     super().__init__(data=data, variables=variables)
#     369     self.estimator = estimator
#     370     self.ci = ci
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_core.py:927, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     923         variables[key] = getattr(val, "name", None)
#     925 # Construct a tidy plot DataFrame. This will convert a number of
#     926 # types automatically, aligning on index in case of pandas objects
# --> 927 plot_data = pd.DataFrame(plot_data)
#     929 # Reduce the variables dictionary to fields with valid data
#     930 variables = {
#     931     var: name
#     932     for var, name in variables.items()
#     933     if plot_data[var].notnull().any()
#     934 }
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File /opt/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/internals/construction.py:688, in _extract_index(data)
#     683     if lengths[0] != len(index):
#     684         msg = (
#     685             f"array length {lengths[0]} does not match index "
#     686             f"length {len(index)}"
#     687         )
# --> 688         raise ValueError(msg)
#     689 else:
#     690     index = default_index(lengths[0])
#
# ValueError: array length 12 does not match index length 2484
