# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import xarray as xr
import torch

import sys
import os.path

sys.path.append(os.path.dirname(os.getcwd()))

from utils.train_test_utils import load_dataset, DatasetParameters


plt.rcParams['figure.figsize'] = (15, 7)

# %%
run_dir = "../output/40_20220509_124142"

# %%
dataset = xr.open_dataarray(f"../data/stocks_daily/stocks_big_dataset_2022-0425.nc")
train_df = pd.read_csv(f"{run_dir}/train_log.csv")
test_df = pd.read_csv(f"{run_dir}/test_results.csv", parse_dates=['Unnamed: 0']).rename({'Unnamed: 0': 'time'}, axis=1)

plt.figure(figsize=(15,7))
# plt.subplot(211)
sns.lineplot(x='epoch', y='train_loss', data=train_df)
# sns.lineplot(x='epoch', y='test_loss', data=train_df)
plt.ylabel('Загуба')
plt.xlabel('Стъпка')
plt.title("Тренировъчна загуба")
# plt.legend(labels=["Train", "Test"])
# Out:
# Text(0.5, 1.0, 'Тренировъчна загуба')

# %%
plt.figure(figsize=(15,7))
# plt.subplot(211)
sns.lineplot(x='epoch', y='train_loss', data=train_df[:20])
# sns.lineplot(x='epoch', y='test_loss', data=train_df)
plt.ylabel('Загуба')
plt.xlabel('Стъпка')
plt.title("Тренировъчна загуба")
# plt.legend(labels=["Train", "Test"])
# Out:
# Text(0.5, 1.0, 'Тренировъчна загуба')

# %%
plt.figure(figsize=(15,7))

# sns.lineplot(x='epoch', y='train_apv', data=train_df)
sns.lineplot(x='epoch', y='test_apv', data=train_df, color='orange')
plt.ylabel('Стойност на портфолиото (APV) върху валидационното множество')
plt.xlabel('Стъпка')
plt.title("APV")
# plt.legend(labels=["Train", "Test"])
# Out:
# Text(0.5, 1.0, 'APV')

# %%
plt.figure(figsize=(15,7))

# sns.lineplot(x='epoch', y='train_apv', data=train_df)
sns.lineplot(x='epoch', y='test_apv', data=train_df[:200], color='orange')
plt.ylabel('APV')
plt.xlabel('Стъпка')
plt.title("Стойност на портфолиото (APV) върху валидационното множество")
# plt.legend(labels=["Train", "Test"])
# Out:
# Text(0.5, 1.0, 'Стойност на портфолиото (APV) върху валидационното множество')

# %%
plt.figure(figsize=(15,7))

# sns.lineplot(x='epoch', y='train_apv', data=train_df)
sns.lineplot(x='epoch', y='test_apv', data=train_df[:10], color='orange')
plt.ylabel('APV')
plt.xlabel('Стъпка')
plt.title("Стойност на портфолиото (APV) върху валидационното множество (5000 стъпки)")
# plt.legend(labels=["Train", "Test"])
# Out:
# Text(0.5, 1.0, 'Стойност на портфолиото (APV) върху валидационното множество (5000 стъпки)')

# %%
plt.figure(figsize=(15,7))

# sns.lineplot(x='epoch', y='train_apv', data=train_df)
sns.lineplot(x='epoch', y='test_apv', data=train_df, color='orange')
plt.ylabel('Portfolio value')
plt.xlabel('Step')
plt.title("Validation APV")
# plt.legend(labels=["Train", "Test"])

# %%
best_epoch = train_df.iloc[np.argmax(train_df['test_apv'])]['epoch']

# %%
best_epoch
# Out:
# 918000

# %%
assets = [re.sub(r"^asset_", "", col) for col in test_df.columns if col.startswith('asset_')]
assets = list(filter(lambda asset: asset != "cash", assets)) + ['cash']

for asset in assets:
    sns.lineplot(x='time', y=f'asset_{asset}', data=test_df)
    
plt.legend(labels=[asset.upper() for asset in assets])
plt.xlabel('Time')
plt.ylabel('Part of portfolio')
# Out:
# Text(0, 0.5, 'Part of portfolio')

# %%
time = dataset.time.to_series()

# %%
first_test_day_idx = np.argwhere(time.index == test_df['time'].iloc[0]).squeeze().item() - 1
last_test_day_idx = np.argwhere(time.index == test_df['time'].iloc[-1]).squeeze().item()

test_dataset = dataset[:, :, first_test_day_idx:last_test_day_idx+1]

# %%
for asset in assets:
    if asset == "cash":
        continue
    asset_data = test_dataset.sel(asset=asset.upper(), feature='close').to_series()

    sns.lineplot(data=asset_data/asset_data[0])
    
    
plt.legend(labels=[asset.upper() for asset in assets if asset != "cash"])
plt.xlabel('Time')
plt.ylabel('Price change')
# Out:
# Text(0, 0.5, 'Price change')

# %%
plt.figure(figsize=(15, 7))

asset = 'msft'

asset_data = test_dataset.sel(asset=asset.upper(), feature='close').to_series()

ax = sns.lineplot(data=asset_data)
plt.ylabel(f'{asset.upper()} price')
ax2 = ax.twinx()
plt.ylabel(f'Portfolio part')


sns.lineplot(x='time', y=test_df[f'asset_{asset}'], data=test_df, ax=ax2, color='orange')
# Out:
# <AxesSubplot:xlabel='time', ylabel='Portfolio part'>

# %%
plt.figure(figsize=(15, 7))

ax = sns.lineplot(x='time', y=test_df[f'asset_{asset}'], data=test_df, color='orange')

plt.ylabel(f'Portfolio part')
ax2 = ax.twinx()
plt.ylabel(f'Price change')

sns.lineplot(x='time', y=test_df[f'price_change_{asset}'], data=test_df, ax=ax2, color='red')
# Out:
# <AxesSubplot:xlabel='time', ylabel='Price change'>

# %%
# plt.figure(figsize=(15, 7))


# asset = 'spy'

# asset_data = dataset.sel(asset=asset.upper(), feature='close').to_series()
# asset_data = asset_data[asset_data.index >= test_df['time'][0]]
# # asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index < '2008-12-01')]


# plt.title('Our results vs S&P 500')
# sns.lineplot(x='time', y='portfolio_value', data=test_df, color='lime')
# sns.lineplot(data=asset_data/asset_data[0])

# %%
test_df.head()
# Out:
#         time  asset_cash  asset_xom  asset_ge  asset_msft   rewards  \
# 0 2007-11-12    0.468873   0.170926  0.179456    0.180746  0.991908
# 1 2007-11-13    0.296600   0.224576  0.229358    0.249467  1.020521
# 2 2007-11-14    0.250888   0.231515  0.234930    0.282667  0.992844
# 3 2007-11-15    0.241282   0.222354  0.229167    0.307196  0.989611
# 4 2007-11-16    0.250034   0.210788  0.223567    0.315611  1.006557
#
#    portfolio_value  price_change_xom  price_change_ge  price_change_msft
# 0         0.991908          0.973402         0.996613           0.989623
# 1         1.012263          1.027679         1.025098           1.035650
# 2         1.005019          0.993439         0.994899           0.984620
# 3         0.994578          0.978913         0.982056           0.994990
# 4         1.001100          1.007220         1.008875           1.009775

# %%
assets = ['XOM', 'GE', 'MSFT'] #, 'C', 'T', 'BAC', 'PG', 'WMT', 'PFE', 'MO', 'AIG', 'JNJ']

dataset_params = DatasetParameters(
    dataset='../data/stocks_daily/stocks_big_dataset_2022-0425.nc',
    x_window_size=30,
    batch_size=128,
    dataset_date_range=slice('2006-06-01', None),
    dataset_features=['close', 'high', 'low', 'open'],
    dataset_assets=assets,
    train_range=('2010-06-29', '2020-05-01'),
    validation_range=('2020-05-01', '2021-05-01'),
#     test_range=(test_df['time'].iloc[0], test_df['time'].iloc[-1])
#     test_range=('2021-05-01', '2022-04-22')
    test_range=('2021-05-01', None)
)

dm = load_dataset(dataset_params)

test_ds = dm.get_test_set_online(assets, dm._test_ind[0], dm._test_ind[-1]+1, 30, False)

trivial_model_distribution = test_ds['y'][0, 0, :, :].squeeze()

# result = gains.prod(axis=0).mean()
# gain = result - 1

# %%
trivial_model_performance = np.cumprod(trivial_model_distribution, axis=1).mean(axis=0)
trivial_model_performance = np.concatenate([[1], trivial_model_performance])

# %%
asset = 'spy'

asset_data = test_dataset.sel(asset=asset.upper(), feature='close').to_series()
asset_data.shape
# Out:
# (266,)

# %%
trivial_model_performance.shape
# Out:
# (218,)

# %%
our_model_portfolio_value = test_df['portfolio_value'].to_numpy()
our_model_portfolio_value = np.concatenate([[1], our_model_portfolio_value])

# %%
our_model_portfolio_value.shape
# Out:
# (266,)

# %%
plt.figure(figsize=(15, 7))


# asset_data = asset_data[(asset_data.index >= test_df['time'][0]) & (asset_data.index < '2008-12-01')]

# our_model = np.concatenate([[1], test_df['portfolio_value']])

plt.title('Our results vs Buy & Hold')
sns.lineplot(x=asset_data.index, y=our_model_portfolio_value, color='limegreen')

sns.lineplot(x=asset_data.index, y=trivial_model_performance, color='cornflowerblue')

sns.lineplot(data=asset_data/asset_data[0], color='maroon')

plt.legend(labels=["Our model", "Buy & hold", "S&P 500"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 11>()
#       8 plt.title('Our results vs Buy & Hold')
#       9 sns.lineplot(x=asset_data.index, y=our_model_portfolio_value, color='limegreen')
# ---> 11 sns.lineplot(x=asset_data.index, y=trivial_model_performance, color='cornflowerblue')
#      13 sns.lineplot(data=asset_data/asset_data[0], color='maroon')
#      15 plt.legend(labels=["Our model", "Buy & hold", "S&P 500"])
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/relational.py:692, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     677 @_deprecate_positional_args
#     678 def lineplot(
#     679     *,
#    (...)
#     688     legend="auto", ax=None, **kwargs
#     689 ):
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
#     694         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#     695         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#     696     )
#     698     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     699     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/relational.py:367, in _LinePlotter.__init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     353 def __init__(
#     354     self, *,
#     355     data=None, variables={},
#    (...)
#     361     # the kind of plot to draw, but for the time being we need to set
#     362     # this information so the SizeMapping can use it
#     363     self._default_size_range = (
#     364         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     365     )
# --> 367     super().__init__(data=data, variables=variables)
#     369     self.estimator = estimator
#     370     self.ci = ci
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/seaborn/_core.py:927, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     923         variables[key] = getattr(val, "name", None)
#     925 # Construct a tidy plot DataFrame. This will convert a number of
#     926 # types automatically, aligning on index in case of pandas objects
# --> 927 plot_data = pd.DataFrame(plot_data)
#     929 # Reduce the variables dictionary to fields with valid data
#     930 variables = {
#     931     var: name
#     932     for var, name in variables.items()
#     933     if plot_data[var].notnull().any()
#     934 }
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/miniconda3/envs/rat/lib/python3.8/site-packages/pandas/core/internals/construction.py:674, in _extract_index(data)
#     672 lengths = list(set(raw_lengths))
#     673 if len(lengths) > 1:
# --> 674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
#     677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#
# ValueError: All arrays must be of the same length
